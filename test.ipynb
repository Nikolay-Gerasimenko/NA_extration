# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
from LegalDocument import LegalDocument as LD
import re

# %%
document_names = [
                    'Определение Верховного Суда РФ от 10.12.2018 N 310-ЭС18-1678.htm',
                    'Определение Верховного Суда РФ от 10.12.2018 N 305-ЭС18-1282.htm',
                    'Определение Верховного Суда РФ от 10.12.2018 N 305-ЭС18-1564.htm',
                    'Определение Верховного Суда РФ от 10.12.2018 N 305-ЭС18-1703.htm',
                    'Определение Верховного Суда РФ от 10.12.2018 N 305-ЭС18-1726.htm',
                    'Определение Верховного Суда РФ от 10.12.2018 N 306-ЭС17-2034.htm',
                    'Определение Верховного Суда РФ от 10.12.2018 N 306-ЭС18-8105.htm',
                    'Определение Верховного Суда РФ от 10.12.2018 N 307-ЭС18-1126.htm',
                    'Определение Верховного Суда РФ от 10.12.2018 N 308-ЭС17-1033.htm',
                    'Определение Верховного Суда РФ от 13.12.2018 по делу N 305-Э.htm',
                    'Определение Верховного Суда РФ от 11.12.2018 N 305-ЭС18-1761.htm',
                    'Определение Верховного Суда РФ от 11.12.2018 N 5-КГ18-247 Тр.htm',
                    'Определение Верховного Суда РФ от 12.12.2018 N 305-ЭС18-1664.htm',
                    'Определение Верховного Суда РФ от 12.12.2018 N 305-ЭС18-1690.htm',
                    'Определение Верховного Суда РФ от 13.12.2018 N 301-ЭС18-1341.htm',
                    'Определение Верховного Суда РФ от 13.12.2018 N 305-ЭС18-1411.htm',
                    'Определение Верховного Суда РФ от 13.12.2018 N 305-АД18-1492.htm',
                    'Определение Верховного Суда РФ от 13.12.2018 N 305-ЭС18-5703.htm',
                    'Определение Верховного Суда РФ от 13.12.2018 по делу N 303-Э.htm',
                    'Определение Верховного Суда РФ от 13.12.2018 по делу N 308-Э.htm',
                    'Решение Верховного Суда РФ от 13.12.2018 N 53-ААД18-14 Обсто.htm',
                    'Решение Верховного Суда РФ от 13.12.2018 N 65-ААД18-8 Обстоя.htm',
                    'Решение Верховного Суда РФ от 13.12.2018 N 93-ААД18-7 Обстоя.htm',
                    'Определение Верховного Суда РФ от 13.12.2018 N 306-КГ18-1696.htm',
                    'Постановление Верховного Суда РФ от 10.12.2018 N 58-АД18-7 Т.htm',
                    'Постановление Верховного Суда РФ от 13.12.2018 N 18-АД18-57.htm',
                    'Постановление Верховного Суда РФ от 13.12.2018 N 5-АД18-72 Т.htm',
                    'Постановление Верховного Суда РФ от 13.12.2018 N 5-АД18-73 Т.htm',
                    'Постановление Верховного Суда РФ от 13.12.2018 N 5-АД18-74 Т.htm'
                ]

# %%
def get_ld_from_file(document_name):
    return LD(get_text_from_file(document_name))

# %%
def get_text_from_file(document_name):
    soup = BeautifulSoup(open(document_name), "lxml")
    temp = soup.getText()[soup.getText().find('ВЕРХОВНЫЙ СУД РОССИЙСКОЙ ФЕДЕРАЦИИ'):]
    text = temp[:temp.find('Документ предоставлен КонсультантПлюс')]
    return text

# %%
df = pd.read_excel('./разметка.xlsx')

# %% [markdown]
# ## Проверка извлечения na_string

# %%
i=0
for document_name in document_names:
    fn = []
    tp = []
    fp = []
    
    for na_string in LD.get_na_strings(get_text_from_file(document_name)):
        if na_string not in df[df['document']==document_name]['entity']:
            tp.append(na_string)
        else:
            fp.append(na_string)

    for na_string in df[df['document']==document_name]['entity']:
        if na_string not in LD.get_na_strings(get_text_from_file(document_name)):
            fn.append(na_string)
    
    if True:#len(fn+fp)!=0: 
        print(i)
        print(document_name)
        print('TP:\n{}'.format(tp))
        print('FP:\n{}'.format(fp))
        print('FN:\n{}'.format(fn))
        print('__________________________________________________')
    
    i+=1
# Out:
# 0
# Определение Верховного Суда РФ от 10.12.2018 N 310-ЭС18-1678.htm
# TP:
# ['главы 29 Арбитражного процессуального кодекса Российской Федерации', 'пунктом 2 части 7 статьи 291.6 АПК РФ', 'главы 7 АПК РФ', 'статей 1225, 1252, 1484, 1515 Гражданского кодекса Российской Федерации', 'статьи 110 АПК РФ', 'пункту 3 статьи 1252 ГК РФ', 'статьями 291.6, 291.9 АПК РФ']
# FP:
# []
# FN:
# []
# __________________________________________________
# 1
# Определение Верховного Суда РФ от 10.12.2018 N 305-ЭС18-1282.htm
# TP:
# ['статьи 395 Гражданского кодекса Российской Федерации', 'статьи 163 Арбитражного процессуального кодекса Российской Федерации', 'части 2 статьи 291.10 Арбитражного процессуального кодекса Российской Федерации', 'статьи 395 Гражданского кодекса Российской Федерации', 'статье 395 Гражданского кодекса Российской Федерации', 'статье 395 Гражданского кодекса Российской Федерации', 'пункта 2 статьи 363 Гражданского кодекса Российской Федерации', 'пункта 1 статьи 361, пунктов 1, 2 статьи 363 Гражданского кодекса Российской Федерации', 'части 1 статьи 291.11 и пункта 4 части 1 статьи 291.14 Арбитражного процессуального кодекса Российской Федерации', 'статьями 291.11, 291.13 - 291.15 Арбитражного процессуального кодекса Российской Федерации']
# FP:
# []
# FN:
# []
# __________________________________________________
# 2
# Определение Верховного Суда РФ от 10.12.2018 N 305-ЭС18-1564.htm
# TP:
# ['статьи 156 Арбитражного процессуального кодекса Российской Федерации', 'статьями 230, 233 Арбитражного процессуального кодекса Российской Федерации', 'часть 1 статьи 291.11 Арбитражного процессуального кодекса Российской Федерации', 'статьи 291.14 Арбитражного процессуального кодекса Российской Федерации', 'часть 2 статьи 230 Арбитражного процессуального кодекса Российской Федерации', 'частью 2 статьи 233 Арбитражного процессуального кодекса Российской Федерации', 'пунктом 2 части 4 статьи 233 Арбитражного процессуального кодекса Российской Федерации', 'пунктом 2 части 4 статьи 233 Арбитражного процессуального кодекса Российской Федерации', 'пункта 1 части 1 статьи 291.14 Арбитражного процессуального кодекса Российской Федерации', 'статьями 167, 176, 291.11 - 291.15 Арбитражного процессуального кодекса Российской Федерации']
# FP:
# []
# FN:
# []
# __________________________________________________
# 3
# Определение Верховного Суда РФ от 10.12.2018 N 305-ЭС18-1703.htm
# TP:
# ['пунктам 1 и 2 части 7 статьи 291.6 Арбитражного процессуального кодекса Российской Федерации', 'часть 1 статьи 291.11 Арбитражного процессуального кодекса Российской Федерации', 'статьи 71 Арбитражного процессуального кодекса Российской Федерации', 'статьями 1229, 1252, 1259, 1270, 1484, 1515 Гражданского кодекса Российской Федерации', 'абзаца 3 пункта 3 статьи 1252, подпункта 1 статьи 1301, подпункта 1 пункта 4 статьи 1515 Гражданского кодекса Российской Федерации', 'статьями 291.6, 291.9 Арбитражного процессуального кодекса Российской Федерации']
# FP:
# []
# FN:
# []
# __________________________________________________
# 4
# Определение Верховного Суда РФ от 10.12.2018 N 305-ЭС18-1726.htm
# TP:
# ['статьей 78 Бюджетного кодекса Российской Федерации', 'пункт 3 статьи 69 Воздушного кодекса Российской Федерации', 'части 1 статьи 291.1, части 7 статьи 291.6, статьи 291.11 Арбитражного процессуального кодекса Российской Федерации', 'статьями 291.6, 291.9 Арбитражного процессуального кодекса Российской Федерации']
# FP:
# []
# FN:
# []
# __________________________________________________
# 5
# Определение Верховного Суда РФ от 10.12.2018 N 306-ЭС17-2034.htm
# TP:
# ['статьи 324 Арбитражного процессуального кодекса Российской Федерации', 'статьи 324 Арбитражного процессуального кодекса Российской Федерации', 'статьи 324 Арбитражного процессуального кодекса Российской Федерации', 'части 1 статьи 324 Арбитражного процессуального кодекса Российской Федерации', 'части 1 статьи 291.11 Арбитражного процессуального кодекса Российской Федерации', 'статьями 291.11 - 291.14 Арбитражного процессуального кодекса Российской Федерации']
# FP:
# []
# FN:
# []
# __________________________________________________
# 6
# Определение Верховного Суда РФ от 10.12.2018 N 306-ЭС18-8105.htm
# TP:
# ['статьи 156 Арбитражного процессуального кодекса Российской Федерации', 'часть 1 статьи 291.11 Арбитражного процессуального кодекса Российской Федерации', 'статьи 291.14 Арбитражного процессуального кодекса Российской Федерации', 'частью 2 статьи 236 Арбитражного процессуального кодекса Российской Федерации', 'часть 4 статьи 238 Арбитражного процессуального кодекса Российской Федерации', 'пунктом 2 части 4 статьи 239 Арбитражного процессуального кодекса Российской Федерации', 'пунктом 2 части 4 статьи 239 Арбитражного процессуального кодекса Российской Федерации', 'пункта 1 части 1 статьи 291.14 Арбитражного процессуального кодекса Российской Федерации', 'статьями 167, 176, 291.11 - 291.15 Арбитражного процессуального кодекса Российской Федерации']
# FP:
# []
# FN:
# []
# __________________________________________________
# 7
# Определение Верховного Суда РФ от 10.12.2018 N 307-ЭС18-1126.htm
# TP:
# ['пункту 2 части 1 статьи 150 Арбитражного процессуального кодекса Российской Федерации', 'пункта 2 части 1 статьи 150 Арбитражного процессуального кодекса Российской Федерации', 'пункта 1 статьи 1050 Гражданского кодекса Российской Федерации', 'пункт 2 статьи 1050 Гражданского кодекса Российской Федерации', 'пункта 1 статьи 291.11 Арбитражного процессуального кодекса Российской Федерации', 'статьями 291.11 - 291.14 Арбитражного процессуального кодекса Российской Федерации']
# FP:
# []
# FN:
# []
# __________________________________________________
# 8
# Определение Верховного Суда РФ от 10.12.2018 N 308-ЭС17-1033.htm
# TP:
# ['пункт 3 статьи 9, пункты 2, 4 статьи 66 АПК РФ', 'статьи 6, 8, 9 Арбитражного процессуального кодекса Российской Федерации', 'пункта 1 статьи 291.11 Арбитражного процессуального кодекса Российской Федерации', 'статьями 291.11 - 291.14 Арбитражного процессуального кодекса Российской Федерации']
# FP:
# []
# FN:
# []
# __________________________________________________
# 9
# Определение Верховного Суда РФ от 13.12.2018 по делу N 305-Э.htm
# TP:
# ['части 1 статьи 49 Арбитражного процессуального кодекса Российской Федерации', 'части 1 статьи 49 АПК РФ', 'статьи 291.14 АПК РФ', 'статей 15, 393, 900, 904 Гражданского кодекса Российской Федерации', 'статей 15, 393, 886, 900 Гражданского кодекса', 'пункту 1 статьи 15 Гражданского кодекса', 'Пункт 2 статьи 15 Гражданского кодекса', 'статьи 15 Гражданского кодекса', 'статьи 15 Гражданского кодекса', 'статьи 431 Гражданского кодекса', 'части 1 статьи 291.11 АПК РФ', 'статьями 176, 291.11 - 291.15 АПК РФ']
# FP:
# []
# FN:
# []
# __________________________________________________
# 10
# Определение Верховного Суда РФ от 11.12.2018 N 305-ЭС18-1761.htm
# TP:
# ['части 1 статьи 291.1, части 7 статьи 291.6, статьи 291.11 Арбитражного процессуального кодекса Российской Федерации', 'статьи 71 АПК РФ', 'пунктом 2 части 7 статьи 291.6 Арбитражного процессуального кодекса Российской Федерации']
# FP:
# []
# FN:
# []
# __________________________________________________
# 11
# Определение Верховного Суда РФ от 11.12.2018 N 5-КГ18-247 Тр.htm
# TP:
# ['ст. 387 Гражданского процессуального кодекса Российской Федерации', 'п. 1 ст. 810 Гражданского кодекса Российской Федерации', 'ст. 809 Гражданского кодекса Российской Федерации', 'п. 1 ст. 200 Гражданского кодекса Российской Федерации', 'п. 1 ст. 200 Гражданского кодекса Российской Федерации', 'п. 1 ст. 196 Гражданского кодекса Российской Федерации', 'ст. ст. 387, 388, 390 Гражданского процессуального кодекса Российской Федерации']
# FP:
# []
# FN:
# []
# __________________________________________________
# 12
# Определение Верховного Суда РФ от 12.12.2018 N 305-ЭС18-1664.htm
# TP:
# ['пунктам 1 и 2 части 7 статьи 291.6 Арбитражного процессуального кодекса Российской Федерации', 'часть 1 статьи 291.11 АПК РФ', 'статью 69 АПК РФ', 'статьи 328, 405, 606, 611, 614 Гражданского кодекса Российской Федерации', 'статьи 328 ГК РФ', 'статей 1, 65 Земельного кодекса Российской Федерации', 'статей 309, 310, 614 ГК РФ', 'статью 69 АПК РФ', 'статьей 184, пунктом 2 части 7 статьи 291.6, статьей 291.9 Арбитражного процессуального кодекса Российской Федерации']
# FP:
# []
# FN:
# []
# __________________________________________________
# 13
# Определение Верховного Суда РФ от 12.12.2018 N 305-ЭС18-1690.htm
# TP:
# ['статей 233, 239 Арбитражного процессуального кодекса Российской Федерации', 'части 1 статьи 291.1, части 7 статьи 291.6, статьи 291.11 Арбитражного процессуального кодекса Российской Федерации', 'частью 4 статьи 233 Арбитражного процессуального кодекса Российской Федерации', 'статьей 184, пунктом 2 части 7 статьи 291.6 Арбитражного процессуального кодекса Российской Федерации']
# FP:
# []
# FN:
# []
# __________________________________________________
# 14
# Определение Верховного Суда РФ от 13.12.2018 N 301-ЭС18-1341.htm
# TP:
# ['статьи 291.14 Арбитражного процессуального кодекса Российской Федерации', 'статье 710 Гражданского кодекса Российской Федерации', 'статьи 710 ГК РФ', 'статей 271, 289 Арбитражного процессуального кодекса Российской Федерации', 'статьи 710 ГК РФ', 'статьи 710 ГК РФ', 'статьями 167, 176, 291.11 - 291.15 Арбитражного процессуального кодекса Российской Федерации']
# FP:
# []
# FN:
# []
# __________________________________________________
# 15
# Определение Верховного Суда РФ от 13.12.2018 N 305-ЭС18-1411.htm
# TP:
# ['статей 382, 384 и 388 Гражданского кодекса Российской Федерации', 'пункта 1 статьи 384 Гражданского кодекса Российской Федерации', 'пункта 3 статьи 388 Гражданского кодекса Российской Федерации', 'пункт 5 статьи 859 Гражданского кодекса Российской Федерации', 'статья 383, пункт 2 статьи 388, статья 845 Гражданского кодекса Российской Федерации', 'части 1 статьи 291.11 Арбитражного процессуального кодекса Российской Федерации', 'статьи 71 Арбитражного процессуального кодекса Российской Федерации', 'статьями 291.11 - 291.14 Арбитражного процессуального кодекса Российской Федерации']
# FP:
# []
# FN:
# []
# __________________________________________________
# 16
# Определение Верховного Суда РФ от 13.12.2018 N 305-АД18-1492.htm
# TP:
# ['части 2 статьи 15.15.5 Кодекса Российской Федерации об административных правонарушениях', 'часть 1 статьи 291.11 Арбитражного процессуального кодекса Российской Федерации', 'статьи 291.14 АПК РФ', 'части 2 статьи 15.15.5 КоАП РФ', 'Часть 2 статьи 15.15.5 КоАП РФ', 'части 2 статьи 15.15.5 КоАП РФ', 'части 2 статьи 2.1 КоАП РФ', 'части 1 статьи 291.14 АПК РФ', 'статьями 176, 291.11 - 291.15 Арбитражного процессуального кодекса Российской Федерации', 'части 2 статьи 15.15.5 Кодекса Российской Федерации об административных правонарушениях']
# FP:
# []
# FN:
# []
# __________________________________________________
# 17
# Определение Верховного Суда РФ от 13.12.2018 N 305-ЭС18-5703.htm
# TP:
# ['пункта 7 части 1 статьи 148 Арбитражного процессуального кодекса Российской Федерации', 'части 1 статьи 291.11 Арбитражного процессуального кодекса Российской Федерации', 'статьями 291.11 - 291.14 Арбитражного процессуального кодекса Российской Федерации']
# FP:
# []
# FN:
# []
# __________________________________________________
# 18
# Определение Верховного Суда РФ от 13.12.2018 по делу N 303-Э.htm
# TP:
# ['статьи 426 Гражданского кодекса Российской Федерации', 'подпункт 1.1 пункта 1 статьи 333.37 Налогового кодекса Российской Федерации', 'части 2 статьи 291.10 Арбитражного процессуального кодекса Российской Федерации', 'статьями 10, 166, 167, 168, 421, 432 Гражданского кодекса Российской Федерации', 'статьи 71 Арбитражного процессуального кодекса Российской Федерации', 'статьей 333.37 Налогового кодекса Российской Федерации', 'статьей 6 Бюджетного кодекса Российской Федерации', 'пункт 2 статьи 10 и часть 2 статьи 166 Гражданского кодекса Российской Федерации', 'подпунктом 1.1 пункта 1 статьи 333.37 НК РФ', 'подпункта 1.1 пункта 1 статьи 333.37 НК РФ', 'подпункта 1.1 пункта 1 статьи 333.37 НК РФ', 'подпункт 1 пункта 1 статьи 333.37 НК РФ', 'подпунктом 1.1 пункта 1 статьи 333.37 НК РФ', 'статьями 184, 291.13 - 291.15 Арбитражного процессуального кодекса Российской Федерации']
# FP:
# []
# FN:
# []
# __________________________________________________
# 19
# Определение Верховного Суда РФ от 13.12.2018 по делу N 308-Э.htm
# TP:
# ['статьей 49 Арбитражного процессуального кодекса Российской Федерации', 'частью 2 статьи 291.10 АПК РФ', 'часть 1 статьи 291.11 АПК РФ', 'пункта 3 статьи 1228 Гражданского кодекса Российской Федерации', 'абзаца 3 пункта 1 статьи 1229 ГК РФ', 'статье 1257 ГК РФ', 'статьями 1228, 1229, 1250, 1252, 1259, 1270, 1301 ГК РФ', 'статей 15, 170, 271, 289 АПК РФ', 'частью 2 статьи 291.14 АПК РФ', 'пункта 1 статьи 1259 ГК РФ', 'пункту 1 статьи 1270 ГК РФ', 'подпунктами 1, 2 и 9 пункта 2 статьи 1270 ГК РФ', 'статье 12 и пункте 1 статьи 1252 ГК РФ', 'пункта 3 статьи 1252 ГК РФ', 'пункте 2 статьи 1270 ГК РФ', 'пункте 2 статьи 1270 ГК РФ', 'пункта 2 статьи 1270 ГК РФ', 'части 1 статьи 291.11 АПК РФ', 'статьями 176, 291.11 - 291.15 АПК РФ']
# FP:
# []
# FN:
# []
# __________________________________________________
# 20
# Решение Верховного Суда РФ от 13.12.2018 N 53-ААД18-14 Обсто.htm
# TP:
# ['частью 2 статьи 12.2 Кодекса Российской Федерации об административных правонарушениях', 'частью 2 статьи 12.2 Кодекса Российской Федерации об административных правонарушениях', 'статей 30.1 - 30.2 Кодекса Российской Федерации об административных правонарушениях', 'статей 30.9, 30.1 - 30.2 Кодекса Российской Федерации об административных правонарушениях', 'статей 30.9, 30.1 - 30.2 Кодекса Российской Федерации об административных правонарушениях', 'главой 30 Кодекса Российской Федерации об административных правонарушениях', 'статьями 30.1 - 30.3, 30.9, 30.10 Кодекса Российской Федерации об административных правонарушениях', 'части 2 статьи 30.8 Кодекса Российской Федерации об административных правонарушениях', 'части 1 статьи 30.3 Кодекса Российской Федерации об административных правонарушениях', 'часть 2 статьи 30.3 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 30.3 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 30.3 Кодекса Российской Федерации об административных правонарушениях', 'статьями 30.12 - 30.14 Кодекса Российской Федерации об административных правонарушениях', 'статьями 30.1 - 30.3, 30.7 Кодекса Российской Федерации об административных правонарушениях', 'частью 2 статьи 12.2 Кодекса Российской Федерации об административных правонарушениях']
# FP:
# []
# FN:
# []
# __________________________________________________
# 21
# Решение Верховного Суда РФ от 13.12.2018 N 65-ААД18-8 Обстоя.htm
# TP:
# ['частью 2 статьи 8.21 Кодекса Российской Федерации об административных правонарушениях', 'частью 2 статьи 8.21 Кодекса Российской Федерации об административных правонарушениях', 'статей 30.1 - 30.2 Кодекса Российской Федерации об административных правонарушениях', 'статей 30.9, 30.1 - 30.2 Кодекса Российской Федерации об административных правонарушениях', 'части 1 статьи 25.1 и частей 1, 2 статьи 25.5 Кодекса Российской Федерации об административных правонарушениях', 'части 3 статьи 25.5 Кодекса Российской Федерации об административных правонарушениях', 'частей 2 и 3 статьи 53 Гражданского процессуального кодекса Российской Федерации', 'статей 30.9, 30.1 - 30.2 Кодекса Российской Федерации об административных правонарушениях', 'статьями 30.1, 30.7 Кодекса Российской Федерации об административных правонарушениях', 'частью 2 статьи 8.21 Кодекса Российской Федерации об административных правонарушениях']
# FP:
# []
# FN:
# []
# __________________________________________________
# 22
# Решение Верховного Суда РФ от 13.12.2018 N 93-ААД18-7 Обстоя.htm
# TP:
# ['частью 1.1 статьи 18.8 Кодекса Российской Федерации об административных правонарушениях', 'частью 1.1 статьи 18.8 Кодекса Российской Федерации об административных правонарушениях', 'части 1 статьи 30.3 Кодекса Российской Федерации об административных правонарушениях', 'часть 2 статьи 30.3 Кодекса Российской Федерации об административных правонарушениях', 'статей 30.1, 30.9 и 30.13 Кодекса Российской Федерации об административных правонарушениях', 'статьями 30.12 - 30.13 Кодекса Российской Федерации об административных правонарушениях', 'статьей 30.3 Кодекса Российской Федерации об административных правонарушениях']
# FP:
# []
# FN:
# []
# __________________________________________________
# 23
# Определение Верховного Суда РФ от 13.12.2018 N 306-КГ18-1696.htm
# TP:
# ['части 7 статьи 291.6 Арбитражного процессуального кодекса Российской Федерации', 'части 4 статьи 229.5 Арбитражного процессуального кодекса Российской Федерации', 'пункта 3 статьи 46 и пункта 1 статьи 115 Налогового кодекса Российской Федерации', 'статья 46 Налогового кодекса', 'пункте 3 статьи 48 Налогового кодекса', 'пункта 3 статьи 48 Налогового кодекса', 'пунктом 2 части 7 статьи 291.6, статьей 291.9 Арбитражного процессуального кодекса Российской Федерации']
# FP:
# []
# FN:
# []
# __________________________________________________
# 24
# Постановление Верховного Суда РФ от 10.12.2018 N 58-АД18-7 Т.htm
# TP:
# ['частью 1 статьи 12.26 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 12.26 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 12.26 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 1.6 Кодекса Российской Федерации об административных правонарушениях', 'статьи Кодекса Российской Федерации об административных правонарушениях', 'пункту 3 статьи 29.1 Кодекса Российской Федерации об административных правонарушениях', 'Главой 27 Кодекса Российской Федерации об административных правонарушениях', 'часть 1 статьи 27.12 Кодекса Российской Федерации об административных правонарушениях', 'части 1.1 статьи 27.12 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 27.12.1 Кодекса Российской Федерации об административных правонарушениях', 'часть 3 статьи 27.12, часть 3 статьи 27.12.1 Кодекса Российской Федерации об административных правонарушениях', 'частью 4 статьи 27.12 и частью 4 статьи 27.12.1 Кодекса Российской Федерации об административных правонарушениях', 'части 5 статьи 27.12 и части 5 статьи 27.12.1 Кодекса Российской Федерации об административных правонарушениях', 'части 6 статьи 27.12 Кодекса Российской Федерации об административных правонарушениях', 'частей 3, 5, 6 статьи 27.12 и частей 3, 5 статьи 27.12.1 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 12.26 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 12.26 Кодекса Российской Федерации об административных правонарушениях', 'статей 24.1 и 26.1 Кодекса Российской Федерации об административных правонарушениях', 'части Кодекса Российской Федерации об административных правонарушениях', 'части 3 статьи 26.2 Кодекса Российской Федерации об административных правонарушениях', 'частей 1 и 4 статьи 1.5 Кодекса Российской Федерации об административных правонарушениях', 'пунктом 4 части 2 статьи 30.17 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 12.26 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 12.26 Кодекса Российской Федерации об административных правонарушениях', 'статьями 30.13, 30.17 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 12.26 Кодекса Российской Федерации об административных правонарушениях', 'пункта 4 части 2 статьи 30.17 Кодекса Российской Федерации об административных правонарушениях']
# FP:
# []
# FN:
# []
# __________________________________________________
# 25
# Постановление Верховного Суда РФ от 13.12.2018 N 18-АД18-57.htm
# TP:
# ['частью 10 статьи 12.21.1 Кодекса Российской Федерации об административных правонарушениях', 'частью 10 статьи 12.21.1 Кодекса Российской Федерации об административных правонарушениях', 'частью 10 статьи 12.21.1 Кодекса Российской Федерации об административных правонарушениях', 'частью 10 статьи 12.21.1 Кодекса Российской Федерации об административных правонарушениях', 'частью 3 статьи 12.21.1 Кодекса Российской Федерации об административных правонарушениях', 'статьи 26.11 Кодекса Российской Федерации об административных правонарушениях', 'частью 10 статьи 12.21.1 Кодекса Российской Федерации об административных правонарушениях', 'частью 2 статьи 2.1 Кодекса Российской Федерации об административных правонарушениях', 'частью 10 статьи 12.21.1 Кодекса Российской Федерации об административных правонарушениях', 'статьи 24.1 Кодекса Российской Федерации об административных правонарушениях', 'статьями 3.1, 3.5, 4.1 - 4.3 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 4.5 Кодекса Российской Федерации об административных правонарушениях', 'статьями 30.6, 30.9, 30.16 Кодекса Российской Федерации об административных правонарушениях', 'пунктов 2 - 4 части 2 статьи 30.17 Кодекса Российской Федерации об административных правонарушениях', 'статьи 30.13 и 30.17 Кодекса Российской Федерации об административных правонарушениях', 'частью 10 статьи 12.21.1 Кодекса Российской Федерации об административных правонарушениях']
# FP:
# []
# FN:
# []
# __________________________________________________
# 26
# Постановление Верховного Суда РФ от 13.12.2018 N 5-АД18-72 Т.htm
# TP:
# ['частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'части 1 статьи 32.2 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 32.2 Кодекса Российской Федерации об административных правонарушениях', 'части 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'части 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'статьи 26.11 Кодекса Российской Федерации об административных правонарушениях', 'статьи 24.1 Кодекса Российской Федерации об административных правонарушениях', 'статьи 26.1 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 4.5 Кодекса Российской Федерации об административных правонарушениях', 'части 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'части 3 статьи 25.15 Кодекса Российской Федерации об административных правонарушениях', 'пунктов 2 - 4 части 2 статьи 30.17 Кодекса Российской Федерации об административных правонарушениях', 'частью 3 статьи 30.13 Кодекса Российской Федерации об административных правонарушениях', 'статьями 30.12 - 30.17 Кодекса Российской Федерации об административных правонарушениях', 'статьями 30.13 и 30.17 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях']
# FP:
# []
# FN:
# []
# __________________________________________________
# 27
# Постановление Верховного Суда РФ от 13.12.2018 N 5-АД18-73 Т.htm
# TP:
# ['частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'части 1 статьи 32.2 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 32.2 Кодекса Российской Федерации об административных правонарушениях', 'части 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'части 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'статьи 26.11 Кодекса Российской Федерации об административных правонарушениях', 'статьи 24.1 Кодекса Российской Федерации об административных правонарушениях', 'статьи 26.1 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 4.5 Кодекса Российской Федерации об административных правонарушениях', 'части 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'части 3 статьи 25.15 Кодекса Российской Федерации об административных правонарушениях', 'статьи 30.3 Кодекса Российской Федерации об административных правонарушениях', 'статей 30.3 и 31.1 Кодекса Российской Федерации об административных правонарушениях', 'часть 2 статьи 29.11 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 30.3 Кодекса Российской Федерации об административных правонарушениях', 'пунктов 2 - 4 части 2 статьи 30.17 Кодекса Российской Федерации об административных правонарушениях', 'статьями 30.13 и 30.17 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях']
# FP:
# []
# FN:
# []
# __________________________________________________
# 28
# Постановление Верховного Суда РФ от 13.12.2018 N 5-АД18-74 Т.htm
# TP:
# ['частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'частью 2 статьи 30.16 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'части 1 статьи 32.2 Кодекса Российской Федерации об административных правонарушениях', 'части 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 32.2 Кодекса Российской Федерации об административных правонарушениях', 'статья 24.1 Кодекса Российской Федерации об административных правонарушениях', 'статьей 26.1 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 32.2 Кодекса Российской Федерации об административных правонарушениях', 'пунктом 1 статьи 31.1 Кодекса Российской Федерации об административных правонарушениях', 'части 1 статьи 30.3 Кодекса Российской Федерации об административных правонарушениях', 'статьями 5.1 - 5.25, 5.45 - 5.52, 5.56, 5.58 Кодекса Российской Федерации об административных правонарушениях', 'статьи 30.3, 31.1 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'части 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'статей 24.1, 26.1 Кодекса Российской Федерации об административных правонарушениях', 'частей 1 и 4 статьи 1.5 Кодекса Российской Федерации об административных правонарушениях', 'пунктом 4 части 2 статьи 30.17 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'пункта 2 части 1 статьи 24.5 Кодекса Российской Федерации об административных правонарушениях', 'статьями 30.13 и 30.17 Кодекса Российской Федерации об административных правонарушениях', 'частью 1 статьи 20.25 Кодекса Российской Федерации об административных правонарушениях', 'пункта 2 части 1 статьи 24.5 Кодекса Российской Федерации об административных правонарушениях']
# FP:
# []
# FN:
# []
# __________________________________________________

# %% [markdown]
# ## Проверка извлечения извлечения na из na_string

# %%
i=0
for document_name in document_names:
    if i >= 20 and i not in [25, 26]:
        print(i)
        print(document_name + '\n')
        print(LD(get_text_from_file(document_name)).na_list)
        print('__________________________________________________')
    i+=1
# Out:
# 20
# Решение Верховного Суда РФ от 13.12.2018 N 53-ААД18-14 Обсто.htm
#
# [{'Code': 'CodeOfAdministrativeOffenses', 'Article': '12.2', 'ArticlePart': '2'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '12.2', 'ArticlePart': '2'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.2'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.9'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.2'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.9'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.2'}, {'Code': 'CodeOfAdministrativeOffenses', 'CodeChapter': '30'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.9'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.10'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.2'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.3'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.8', 'ArticlePart': '2'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.3', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.3', 'ArticlePart': '2'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.3', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.3', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.12'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.13'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.14'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.7'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.2'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.3'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '12.2', 'ArticlePart': '2'}]
# __________________________________________________
# 21
# Решение Верховного Суда РФ от 13.12.2018 N 65-ААД18-8 Обстоя.htm
#
# [{'Code': 'CodeOfAdministrativeOffenses', 'Article': '8.21', 'ArticlePart': '2'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '8.21', 'ArticlePart': '2'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.2'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.9'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.2'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '25.1 и', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '25.5', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '25.5', 'ArticlePart': '2'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '25.5', 'ArticlePart': '3'}, {'Code': 'CodeofCivilProcedure', 'Article': '53', 'ArticlePart': '2'}, {'Code': 'CodeofCivilProcedure', 'Article': '53', 'ArticlePart': '3'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.9'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.2'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.7'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '8.21', 'ArticlePart': '2'}]
# __________________________________________________
# 22
# Решение Верховного Суда РФ от 13.12.2018 N 93-ААД18-7 Обстоя.htm
#
# [{'Code': 'CodeOfAdministrativeOffenses', 'Article': '18.8', 'ArticlePart': '1.1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '18.8', 'ArticlePart': '1.1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.3', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.3', 'ArticlePart': '2'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.9'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.13'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.12'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.13'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.3'}]
# __________________________________________________
# 23
# Определение Верховного Суда РФ от 13.12.2018 N 306-КГ18-1696.htm
#
# [{'Code': 'CodeOfCommercialProcedure', 'Article': '291.6', 'ArticlePart': '7'}, {'Code': 'CodeOfCommercialProcedure', 'Article': '229.5', 'ArticlePart': '4'}, {'Code': 'TaxCode', 'Article': '46 и', 'Section': '3'}, {'Code': 'TaxCode', 'Article': '115', 'Section': '1'}, {'Code': 'TaxCode', 'Article': '46'}, {'Code': 'TaxCode', 'Article': '48', 'Section': '3'}, {'Code': 'TaxCode', 'Article': '48', 'Section': '3'}, {'Code': 'CodeOfCommercialProcedure', 'Article': '291.6', 'ArticlePart': '7', 'Section': '2'}, {'Code': 'CodeOfCommercialProcedure', 'Article': '291.9'}]
# __________________________________________________
# 24
# Постановление Верховного Суда РФ от 10.12.2018 N 58-АД18-7 Т.htm
#
# [{'Code': 'CodeOfAdministrativeOffenses', 'Article': '12.26', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '12.26', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '12.26', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '1.6', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '29.1', 'Section': '3'}, {'Code': 'CodeOfAdministrativeOffenses', 'CodeChapter': '27'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '27.12', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '27.12', 'ArticlePart': '1.1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '27.12.1', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '27.12', 'ArticlePart': '3'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '27.12.1', 'ArticlePart': '3'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '27.12 и', 'ArticlePart': '4'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '27.12.1', 'ArticlePart': '4'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '27.12 и', 'ArticlePart': '5'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '27.12.1', 'ArticlePart': '5'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '27.12', 'ArticlePart': '6'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '27.12 и', 'ArticlePart': '3'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '27.12 и', 'ArticlePart': '5'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '27.12 и', 'ArticlePart': '6'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '27.12.1', 'ArticlePart': '3'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '27.12.1', 'ArticlePart': '5'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '12.26', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '12.26', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '24.1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '26.1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '26.2', 'ArticlePart': '3'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '1.5', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '1.5', 'ArticlePart': '4'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.17', 'ArticlePart': '2', 'Section': '4'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '12.26', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '12.26', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.13'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.17'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '12.26', 'ArticlePart': '1'}, {'Code': 'CodeOfAdministrativeOffenses', 'Article': '30.17', 'ArticlePart': '2', 'Section': '4'}]
# __________________________________________________
# 27
# Постановление Верховного Суда РФ от 13.12.2018 N 5-АД18-73 Т.htm
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-3afbd1acd4ff> in <module>()
#       4         print(i)
#       5         print(document_name + '\n')
# ----> 6         print(LD(get_text_from_file(document_name)).na_list)
#       7         print('__________________________________________________')
#       8     i+=1
#
# ~/Library/Mobile Documents/com~apple~CloudDocs/.Trash/Документы — MacBook Pro — Николай/Работа/Поиск похожих/New_Structure/LegalDocument.py in __init__(self, text)
#      62     def __init__(self, text):
#      63         self.text = text
# ---> 64         self.__na_list = [na for na_string in self.get_na_strings(text) for na in self.get_na_from_na_string(self.get_marked_na_string(na_string))]
#      65
#      66     @staticmethod
#
# ~/Library/Mobile Documents/com~apple~CloudDocs/.Trash/Документы — MacBook Pro — Николай/Работа/Поиск похожих/New_Structure/LegalDocument.py in <listcomp>(.0)
#      62     def __init__(self, text):
#      63         self.text = text
# ---> 64         self.__na_list = [na for na_string in self.get_na_strings(text) for na in self.get_na_from_na_string(self.get_marked_na_string(na_string))]
#      65
#      66     @staticmethod
#
# ~/Library/Mobile Documents/com~apple~CloudDocs/.Trash/Документы — MacBook Pro — Николай/Работа/Поиск похожих/New_Structure/LegalDocument.py in get_na_from_na_string(self, na_string)
#      82             if(na_level_match != None):
#      83                 if len(na_list)==0:
# ---> 84                     includes, na_string = self.get_na_level(na_level, na_string)
#      85                     for include in includes:
#      86                         na = NA()
#
# ~/Library/Mobile Documents/com~apple~CloudDocs/.Trash/Документы — MacBook Pro — Николай/Работа/Поиск похожих/New_Structure/LegalDocument.py in get_na_level(self, level_pattern, text)
#     107         if dash_numbers is not None:
#     108             na_level_part_without_dash = na_level_part.group(0)[:dash_numbers.start()] + na_level_part.group(0)[dash_numbers.end():]
# --> 109             ranged_na_levels = re.search('\d+(?=\.)', dash_numbers[0]).group(0)
#     110             punkt_numbers = re.findall('(?<=\.)\d+', dash_numbers[0])
#     111             range_na_levels = [ranged_na_levels + '.{0}'.format(i) for i in range(int(punkt_numbers[0]), int(punkt_numbers[1])+1)]
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %% [markdown]
# ## Составление матрицы сходства

# %%
similarity_matrix = np.array([[get_ld_from_file(doc1).similarity_score(get_ld_from_file(doc2)) / len(get_ld_from_file(doc1).na_set | get_ld_from_file(doc2).na_set) for doc1 in document_names] for doc2 in document_names])
similarity_df = pd.DataFrame(similarity_matrix)
similarity_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-2055d65bd2f1> in <module>()
# ----> 1 similarity_matrix = np.array([[get_ld_from_file(doc1).similarity_score(get_ld_from_file(doc2)) / len(get_ld_from_file(doc1).na_set | get_ld_from_file(doc2).na_set) for doc1 in document_names] for doc2 in document_names])
#       2 similarity_df = pd.DataFrame(similarity_matrix)
#       3 similarity_df
#
# <ipython-input-8-2055d65bd2f1> in <listcomp>(.0)
# ----> 1 similarity_matrix = np.array([[get_ld_from_file(doc1).similarity_score(get_ld_from_file(doc2)) / len(get_ld_from_file(doc1).na_set | get_ld_from_file(doc2).na_set) for doc1 in document_names] for doc2 in document_names])
#       2 similarity_df = pd.DataFrame(similarity_matrix)
#       3 similarity_df
#
# <ipython-input-8-2055d65bd2f1> in <listcomp>(.0)
# ----> 1 similarity_matrix = np.array([[get_ld_from_file(doc1).similarity_score(get_ld_from_file(doc2)) / len(get_ld_from_file(doc1).na_set | get_ld_from_file(doc2).na_set) for doc1 in document_names] for doc2 in document_names])
#       2 similarity_df = pd.DataFrame(similarity_matrix)
#       3 similarity_df
#
# <ipython-input-3-89bdcc1f663b> in get_ld_from_file(document_name)
#       1 def get_ld_from_file(document_name):
# ----> 2     return LD(get_text_from_file(document_name))
#
# ~/Library/Mobile Documents/com~apple~CloudDocs/.Trash/Документы — MacBook Pro — Николай/Работа/Поиск похожих/New_Structure/LegalDocument.py in __init__(self, text)
#      62     def __init__(self, text):
#      63         self.text = text
# ---> 64         self.__na_list = [na for na_string in self.get_na_strings(text) for na in self.get_na_from_na_string(self.get_marked_na_string(na_string))]
#      65
#      66     @staticmethod
#
# ~/Library/Mobile Documents/com~apple~CloudDocs/.Trash/Документы — MacBook Pro — Николай/Работа/Поиск похожих/New_Structure/LegalDocument.py in <listcomp>(.0)
#      62     def __init__(self, text):
#      63         self.text = text
# ---> 64         self.__na_list = [na for na_string in self.get_na_strings(text) for na in self.get_na_from_na_string(self.get_marked_na_string(na_string))]
#      65
#      66     @staticmethod
#
# ~/Library/Mobile Documents/com~apple~CloudDocs/.Trash/Документы — MacBook Pro — Николай/Работа/Поиск похожих/New_Structure/LegalDocument.py in get_na_from_na_string(self, na_string)
#      82             if(na_level_match != None):
#      83                 if len(na_list)==0:
# ---> 84                     includes, na_string = self.get_na_level(na_level, na_string)
#      85                     for include in includes:
#      86                         na = NA()
#
# ~/Library/Mobile Documents/com~apple~CloudDocs/.Trash/Документы — MacBook Pro — Николай/Работа/Поиск похожих/New_Structure/LegalDocument.py in get_na_level(self, level_pattern, text)
#     107         if dash_numbers is not None:
#     108             na_level_part_without_dash = na_level_part.group(0)[:dash_numbers.start()] + na_level_part.group(0)[dash_numbers.end():]
# --> 109             ranged_na_levels = re.search('\d+(?=\.)', dash_numbers[0]).group(0)
#     110             punkt_numbers = re.findall('(?<=\.)\d+', dash_numbers[0])
#     111             range_na_levels = [ranged_na_levels + '.{0}'.format(i) for i in range(int(punkt_numbers[0]), int(punkt_numbers[1])+1)]
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
pd.DataFrame(np.triu(similarity_matrix,k=1)).max()

# %%
pd.DataFrame(np.triu(similarity_matrix,k=1)).max().idxmax()
